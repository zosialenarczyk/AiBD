# %%
import pandas as pd

dataset = pd.read_csv('/home/student/Dokumenty/zofialenarczyk/AiBD/earthquake_data.csv')
df = pd.DataFrame(dataset)
df.head(4)
cols = [2, 7, 8]
df_extracted = df[df.columns[cols]]
df_extracted.to_csv('earthquake_data_extracted.csv')
df_extracted
# Out:
#      Do you think the "Big One" will occur in your lifetime?      Age  \
# 0                                                    No       18 - 29
# 1                                                    No       18 - 29
# 2                                                    No       18 - 29
# 3                                                    No       18 - 29
# 4                                                   Yes       18 - 29
# ...                                                 ...           ...
# 1008                                                 No            60
# 1009                                                 No            60
# 1010                                                 No       30 - 44
# 1011                                                 No       30 - 44
# 1012                                                 No           NaN
#
#      What is your gender?
# 0                    Male
# 1                    Male
# 2                    Male
# ...
