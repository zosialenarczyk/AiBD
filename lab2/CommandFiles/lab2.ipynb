# %%
import pandas as pd
import csv

dataset = pd.read_csv('C:/Users/Zosia/Desktop/przedmioty/AiBD/AiBD/lab2/OriginalData/earthquake_data.csv')
df = pd.DataFrame(dataset)
df.head(4)
# Out:
#   In general, how worried are you about earthquakes?  \
# 0                                 Not at all worried
# 1                                   Somewhat worried
# 2                                     Not so worried
# 3                                     Not so worried
#
#   How worried are you about the Big One, a massive, catastrophic earthquake?  \
# 0                                     Not so worried
# 1                                       Very worried
# 2                                   Somewhat worried
# 3                                     Not so worried
#
#   Do you think the "Big One" will occur in your lifetime?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
#
#   Have you ever experienced an earthquake?  \
# 0              Yes, one or more minor ones
# ...

# %%
#Wybrane kolumny
cols = [2, 7, 8]
df_extracted = df[df.columns[cols]]
df_extracted.to_csv('earthquake_data_extracted.csv')
df_extracted
# Out:
#      Do you think the "Big One" will occur in your lifetime?      Age  \
# 0                                                    No       18 - 29
# 1                                                    No       18 - 29
# 2                                                    No       18 - 29
# 3                                                    No       18 - 29
# 4                                                   Yes       18 - 29
# ...                                                 ...           ...
# 1008                                                 No            60
# 1009                                                 No            60
# 1010                                                 No       30 - 44
# 1011                                                 No       30 - 44
# 1012                                                 No           NaN
#
#      What is your gender?
# 0                    Male
# 1                    Male
# 2                    Male
# ...

# %%
# Zmiana nazw kolumn
col_name = {'In general, how worried are you about earthquakes?':'Q1', 
'How worried are you about the Big One, a massive, catastrophic earthquake?':'Q2', 
'Do you think the "Big One" will occur in your lifetime?':'Q3', 
'Have you ever experienced an earthquake?':'Q4', 
'Have you or anyone in your household taken any precautions for an earthquake (packed an earthquake survival kit, prepared an evacuation plan, etc.)?':'Q5', 
'How familiar are you with the San Andreas Fault line?':'Q6', 
'How familiar are you with the Yellowstone Supervolcano?':'Q7', 
'Age':'Q8', 
'What is your gender?':'Q9', 
'How much total combined money did all members of your HOUSEHOLD earn last year?':'Q10', 
'US Region':'Q11'}

df_changed_cols = df.rename(columns = col_name)
df_changed_cols.to_csv('earthquake_data_changed_cols.csv')
df_changed_cols
# Out:
#                       Q1                  Q2   Q3  \
# 0     Not at all worried      Not so worried   No
# 1       Somewhat worried        Very worried   No
# 2         Not so worried    Somewhat worried   No
# 3         Not so worried      Not so worried   No
# 4         Not so worried      Not so worried  Yes
# ...                  ...                 ...  ...
# 1008  Not at all worried  Not at all worried   No
# 1009      Not so worried    Somewhat worried   No
# 1010      Not so worried   Extremely worried   No
# 1011  Not at all worried      Not so worried   No
# 1012    Somewhat worried      Not so worried   No
#
#                                Q4   Q5                   Q6  \
# 0     Yes, one or more minor ones   No    Somewhat familiar
# 1     Yes, one or more minor ones   No  Not at all familiar
# 2     Yes, one or more minor ones   No        Very familiar
# 3     Yes, one or more minor ones   No        Very familiar
# ...
